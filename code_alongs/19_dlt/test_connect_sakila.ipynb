# %%
import duckdb

# connect to duckdb database
with duckdb.connect("data/sakila.duckdb") as conn:
    actor = conn.sql("from staging.actor;").df()

actor.head()
# Out:
#    actor_id first_name     last_name         last_update       _dlt_load_id  \
# 0       1.0   PENELOPE       GUINESS 2021-03-06 15:51:59  1764757761.462185
# 1       2.0       NICK      WAHLBERG 2021-03-06 15:51:59  1764757761.462185
# 2       3.0         ED         CHASE 2021-03-06 15:51:59  1764757761.462185
# 3       4.0   JENNIFER         DAVIS 2021-03-06 15:51:59  1764757761.462185
# 4       5.0     JOHNNY  LOLLOBRIGIDA 2021-03-06 15:51:59  1764757761.462185
#
#           _dlt_id
# 0  XP1aELU0Y9b1MQ
# 1  3sy4i8hvYa2cIg
# 2  zxYFr5ZBHFQWGw
# 3  2kH74gSm6lhYRQ
# 4  6Jq9ZILDX85HAQ
